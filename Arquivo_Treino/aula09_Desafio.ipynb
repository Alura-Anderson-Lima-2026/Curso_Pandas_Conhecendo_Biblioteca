# %% [markdown]
# #### Aula09 - Desafio: bora praticar?

# %%
import pandas as pd

dados = pd.read_csv('Arquivos_Aula/Aula_4_dados.csv',sep=';')

dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# ##### O time de ML chegou com algumas demandas de última hora para resolvermos nesse momento da análise exploratória. Essas demandas são:

# %% [markdown]
# ##### 1) Calcular a média de quartos dos imóveis:

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala', 

                      'Prédio Inteiro', 'Loja/Salão', 

                      'Galpão/Depósito/Armazém', 

                      'Casa Comercial', 'Terreno Padrão',

                      'Loja Shopping/ Ct Comercial',

                      'Box/Garagem', 'Chácara',

                      'Loteamento/Condomínio', 'Sítio',

                      'Pousada/Chalé', 'Hotel', 'Indústria']


df = dados.query('@imoveis_comerciais not in Tipo')

df['Tipo'].unique()

df_media_quartos = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

df_media_quartos
# Out:
#                            Valor
# Tipo
# Quitinete            1246.840909
# Casa de Vila         1574.369478
# Studio               2400.000000
# Loft                 2557.882353
# Flat                 4546.189076
# Apartamento          4744.614648
# Casa                 6793.454922
# Casa de Condomínio  11952.061245

# %% [markdown]
# ##### 2) Conferir quantos bairros únicos existem na nossa base de dados;

# %%
df['Bairro'].nunique() #  Retorna a quantidade de valores únicos (distintos) em uma coluna ou DataFrame.
#df.shape[0] # Retorna o número total de linhas do DataFrame de forma rápida.
# Out:
# 154

# %% [markdown]
# ##### 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;

# %%
df['Bairro'].describe()
df('Bairro')['Valor']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 df['Bairro'].describe()
# ----> 2 df('Bairro')['Valor']
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ##### 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.
